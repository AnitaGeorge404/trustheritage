# %% [markdown]
# # TrustHeritage Backend Smoke Test
#
# Use this notebook after installing requirements. Replace `sample_path` with an image on your machine.

# %%
from pathlib import Path
import sys

project = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(project))

from modules.pipeline import register_image, verify_image

sample_path = project / 'assets' / 'sample_images' / 'your_image.png'
record = register_image(sample_path, {
    'asset_id': 'demo-asset',
    'title': 'Demo Cultural Heritage Image',
    'category': 'Demo',
    'institution': 'Local Lab'
})
result = verify_image(record['record_path'], record['watermarked_path'], use_semantics=False)
result['scores']
